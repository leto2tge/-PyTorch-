# %%
# %matplotlib inline
import numpy as np
import torch
torch.set_printoptions(edgeitems=2, linewidth=75)

# %%
t_c = torch.tensor([0.5, 14.0, 15.0, 28.0, 11.0,
                    8.0, 3.0, -4.0, 6.0, 13.0, 21.0])
t_u = torch.tensor([35.7, 55.9, 58.2, 81.9, 56.3, 48.9,
                    33.9, 21.8, 48.4, 60.4, 68.4])
t_un = 0.1 * t_u

# %%
def model(t_u, w2, w1, b):
    return w2 * t_u**2 + w1 * t_u + b

# %%
params = torch.tensor([4.0, 1.0, 0.0], requires_grad=True)
learning_rate = 1e-4
optimizer = optim.SGD([params], lr=learning_rate) # <1>

training_loop(
    n_epochs = 5000, 
    optimizer = optimizer,
    params = params, # <1> 
    t_u = t_un,
    t_c = t_c)
# Out:
# Epoch 5, Loss 1916.972656
# Epoch 10, Loss 141.807480
# Epoch 15, Loss 19.223967
# Epoch 20, Loss 10.739697
# Epoch 25, Loss 10.133256
# Epoch 30, Loss 10.070797
# Epoch 35, Loss 10.045960
# Epoch 40, Loss 10.023793
# Epoch 45, Loss 10.001883
# Epoch 50, Loss 9.980053
# Epoch 55, Loss 9.958303
# Epoch 60, Loss 9.936625
# Epoch 65, Loss 9.915021
# Epoch 70, Loss 9.893493
# Epoch 75, Loss 9.872033
# Epoch 80, Loss 9.850648
# Epoch 85, Loss 9.829334
# Epoch 90, Loss 9.808096
# Epoch 95, Loss 9.786930
# Epoch 100, Loss 9.765836
# Epoch 105, Loss 9.744808
# Epoch 110, Loss 9.723856
# Epoch 115, Loss 9.702973
# Epoch 120, Loss 9.682160
# Epoch 125, Loss 9.661422
# Epoch 130, Loss 9.640753
# Epoch 135, Loss 9.620153
# Epoch 140, Loss 9.599624
# Epoch 145, Loss 9.579163
# Epoch 150, Loss 9.558773
# Epoch 155, Loss 9.538450
# Epoch 160, Loss 9.518197
# Epoch 165, Loss 9.498015
# Epoch 170, Loss 9.477897
# Epoch 175, Loss 9.457853
# Epoch 180, Loss 9.437873
# Epoch 185, Loss 9.417962
# ...

# %%
params = torch.tensor([4.0, 1.0, 0.0], requires_grad=True)
learning_rate = 1e-4
optimizer = optim.SGD([params], lr=learning_rate) # <1>

training_loop(
    n_epochs = 5000, 
    optimizer = optimizer,
    params = params, # <1> 
    t_u = t_un,
    t_c = t_c)
# Out:
# Epoch 5, Loss 1916.972656
# Epoch 10, Loss 141.807480
# Epoch 15, Loss 19.223967
# Epoch 20, Loss 10.739697
# Epoch 25, Loss 10.133256
# Epoch 30, Loss 10.070797
# Epoch 35, Loss 10.045960
# Epoch 40, Loss 10.023793
# Epoch 45, Loss 10.001883
# Epoch 50, Loss 9.980053
# Epoch 55, Loss 9.958303
# Epoch 60, Loss 9.936625
# Epoch 65, Loss 9.915021
# Epoch 70, Loss 9.893493
# Epoch 75, Loss 9.872033
# Epoch 80, Loss 9.850648
# Epoch 85, Loss 9.829334
# Epoch 90, Loss 9.808096
# Epoch 95, Loss 9.786930
# Epoch 100, Loss 9.765836
# Epoch 105, Loss 9.744808
# Epoch 110, Loss 9.723856
# Epoch 115, Loss 9.702973
# Epoch 120, Loss 9.682160
# Epoch 125, Loss 9.661422
# Epoch 130, Loss 9.640753
# Epoch 135, Loss 9.620153
# Epoch 140, Loss 9.599624
# Epoch 145, Loss 9.579163
# Epoch 150, Loss 9.558773
# Epoch 155, Loss 9.538450
# Epoch 160, Loss 9.518197
# Epoch 165, Loss 9.498015
# Epoch 170, Loss 9.477897
# Epoch 175, Loss 9.457853
# Epoch 180, Loss 9.437873
# Epoch 185, Loss 9.417962
# ...

# %%
params = torch.tensor([4.0, 1.0, 0.0], requires_grad=True)
learning_rate = 1e-4
optimizer = optim.SGD([params], lr=learning_rate) # <1>

training_loop(
    n_epochs = 5000, 
    optimizer = optimizer,
    params = params, # <1> 
    t_u = t_un,
    t_c = t_c)
# Out:
# Epoch 5, Loss 1916.972656
# Epoch 10, Loss 141.807480
# Epoch 15, Loss 19.223967
# Epoch 20, Loss 10.739697
# Epoch 25, Loss 10.133256
# Epoch 30, Loss 10.070797
# Epoch 35, Loss 10.045960
# Epoch 40, Loss 10.023793
# Epoch 45, Loss 10.001883
# Epoch 50, Loss 9.980053
# Epoch 55, Loss 9.958303
# Epoch 60, Loss 9.936625
# Epoch 65, Loss 9.915021
# Epoch 70, Loss 9.893493
# Epoch 75, Loss 9.872033
# Epoch 80, Loss 9.850648
# Epoch 85, Loss 9.829334
# Epoch 90, Loss 9.808096
# Epoch 95, Loss 9.786930
# Epoch 100, Loss 9.765836
# Epoch 105, Loss 9.744808
# Epoch 110, Loss 9.723856
# Epoch 115, Loss 9.702973
# Epoch 120, Loss 9.682160
# Epoch 125, Loss 9.661422
# Epoch 130, Loss 9.640753
# Epoch 135, Loss 9.620153
# Epoch 140, Loss 9.599624
# Epoch 145, Loss 9.579163
# Epoch 150, Loss 9.558773
# Epoch 155, Loss 9.538450
# Epoch 160, Loss 9.518197
# Epoch 165, Loss 9.498015
# Epoch 170, Loss 9.477897
# Epoch 175, Loss 9.457853
# Epoch 180, Loss 9.437873
# Epoch 185, Loss 9.417962
# ...

# %%
def loss_fn(t_p, t_c):
    squared_diffs = (t_p - t_c)**2
    return squared_diffs.mean()

# %%
import torch.optim as optim

dir(optim)
# Out:
# ['ASGD',
#  'Adadelta',
#  'Adagrad',
#  'Adam',
#  'AdamW',
#  'Adamax',
#  'LBFGS',
#  'NAdam',
#  'Optimizer',
#  'RAdam',
#  'RMSprop',
#  'Rprop',
#  'SGD',
#  'SparseAdam',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_functional',
#  '_multi_tensor',
#  'lr_scheduler',
#  'swa_utils']

# %%
params = torch.tensor([1.0, 1.0, 0.0], requires_grad=True)
learning_rate = 1e-5
optimizer = optim.SGD([params], lr=learning_rate)

# %%
params = torch.tensor([1.0, 1.0, 0.0], requires_grad=True)
learning_rate = 1e-2
optimizer = optim.SGD([params], lr=learning_rate)

t_p = model(t_un, *params)
loss = loss_fn(t_p, t_c)

optimizer.zero_grad() # <1>
loss.backward()
optimizer.step()

params
# Out:
# tensor([-16.3953,  -1.7968,  -0.4818], requires_grad=True)

# %%
def training_loop(n_epochs, optimizer, params, t_u, t_c):
    for epoch in range(1, n_epochs + 1):
        t_p = model(t_u, *params) 
        loss = loss_fn(t_p, t_c)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if epoch % 5 == 0:
            print('Epoch %d, Loss %f' % (epoch, float(loss)))
            
    return params

# %%
params = torch.tensor([4.0, 1.0, 0.0], requires_grad=True)
learning_rate = 1e-4
optimizer = optim.SGD([params], lr=learning_rate) # <1>

training_loop(
    n_epochs = 5000, 
    optimizer = optimizer,
    params = params, # <1> 
    t_u = t_un,
    t_c = t_c)
# Out:
# Epoch 5, Loss 1916.972656
# Epoch 10, Loss 141.807480
# Epoch 15, Loss 19.223967
# Epoch 20, Loss 10.739697
# Epoch 25, Loss 10.133256
# Epoch 30, Loss 10.070797
# Epoch 35, Loss 10.045960
# Epoch 40, Loss 10.023793
# Epoch 45, Loss 10.001883
# Epoch 50, Loss 9.980053
# Epoch 55, Loss 9.958303
# Epoch 60, Loss 9.936625
# Epoch 65, Loss 9.915021
# Epoch 70, Loss 9.893493
# Epoch 75, Loss 9.872033
# Epoch 80, Loss 9.850648
# Epoch 85, Loss 9.829334
# Epoch 90, Loss 9.808096
# Epoch 95, Loss 9.786930
# Epoch 100, Loss 9.765836
# Epoch 105, Loss 9.744808
# Epoch 110, Loss 9.723856
# Epoch 115, Loss 9.702973
# Epoch 120, Loss 9.682160
# Epoch 125, Loss 9.661422
# Epoch 130, Loss 9.640753
# Epoch 135, Loss 9.620153
# Epoch 140, Loss 9.599624
# Epoch 145, Loss 9.579163
# Epoch 150, Loss 9.558773
# Epoch 155, Loss 9.538450
# Epoch 160, Loss 9.518197
# Epoch 165, Loss 9.498015
# Epoch 170, Loss 9.477897
# Epoch 175, Loss 9.457853
# Epoch 180, Loss 9.437873
# Epoch 185, Loss 9.417962
# ...
